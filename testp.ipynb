# %%
from app import test

test()
# Out:
# app
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from app import test
#       2
#       3 test()
#
# ImportError: cannot import name 'test' from 'app' (c:\Users\KDT-17\Documents\17-job-scraper\app.py)

# %%
from app import test

test()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from app import test
#       2
#       3 test()
#
# ImportError: cannot import name 'test' from 'app' (c:\Users\KDT-17\Documents\17-job-scraper\app.py)
